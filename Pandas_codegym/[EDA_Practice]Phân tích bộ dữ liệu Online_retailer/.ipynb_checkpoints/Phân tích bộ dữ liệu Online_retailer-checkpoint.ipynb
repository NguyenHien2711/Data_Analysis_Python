# %% [markdown]
# Bộ dữ liệu Online Retail chứa dữ liệu về giao dịch mua sắm online, các thông tin được thống kê bao gồm: <br>
#
# InvoiceNo: Số hóa đơn<br>
# StockCode: Mã kho<br>
# Description: Mô tả<br>
# Quantity: Số lượng<br>
# InvoiceDate: Ngày mua<br>
# UnitPrice: Giá<br>
# CustomerID: Mã khách hàng<br>
# Country: Quốc gia<br>
# 1. Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính, tiền xử lý dữ liệu<br>
# - Phát hiện các dòng, cột chứa dữ liệu khuyết thiếu<br>
# - Có nên xóa hết các dòng chứa dữ liệu khuyết thiếu, giải thích vì sao<br>
# - Thực hiện xử lý giá trị khuyết thiếu: Thay thế giá trị khuyết thiếu của thuộc tính Description bằng giá trị mặc định “Không biết”<br>
#
# 2. Xây dựng bảng Pivot table, với mỗi Số hóa đơn tính trung bình cộng số lượng các mặt hàng theo từng Quốc gia. <br>
# 3. Xây dựng bảng Pivot table, với mỗi Khách hàng cho biết số lượng mua hàng lớn nhất và nhỏ nhất theo Kho.<br>
# 4. Xây dựng bảng Pivot table, với mỗi Mã kho tính tổng số lượng các mặt hàng và trung bình cộng giá.<br>
# 5. Xây dựng bảng Pivot table cho biết tổng số lượng hàng bán được của mỗi ngày.<br>
# 6. Tạo cột mới có tên quý –  ‘Previous’ nhận giá trị 1 nếu ngày lập hóa đơn nằm trong các tháng 1,2,3; nhận giá trị 2 nếu ngày lập hóa đơn nằm trong các tháng 4,5,6; nhận giá trị 3 nếu ngày lập hóa đơn nằm trong các tháng 7,8,9;  nhận giá trị 4 nếu ngày lập hóa đơn nằm trong các tháng 10,11,12;<br>
# 7. Tạo một cột mới có tên ‘Amount’ có giá trị bằng Quantity * UnitPrice<br>
# 8. Tạo cột mới ‘Discount’ nhận giá trị 10% nếu Country là ‘United Kingdom’ và thuộc quý 4, 5% nếu là ‘France’ ngược lại là 0%.<br>
# 9. Tạo cột mới ‘Total’ nhận giá trị bằng: Amount – Discount.<br>
# 10.Công ty bán hàng do bao nhiêu nước sản xuất<br>
# 11.Tổng số lượng đơn hàng bán ra, tổng doanh thu<br>
# 12.Top 10 mặt hàng có số lượng bán ra lớn nhất<br>
# 13.Top 10 mặt hàng có doanh thu lớn nhất

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
df = pd.read_csv('OnlineRetail.csv', encoding= 'unicode_escape')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #### 1. Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# Phát hiện các dòng, cột chứa dữ liệu khuyết thiếu

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# Description      1454
# CustomerID     135080
# dtype: int64

# %% [markdown]
# Description có dữ liệu khuyết thiếu, nhưng không cần phải loại bỏ, CustomerID có dữ liệu khuyết thiếu, trước mắt chưa cần loại bỏ

# %%
df['Description'].fillna(value='Không biết', inplace=True)

df[df['Description']=='Không biết']
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139  Không biết        56  12/1/2010 11:52        0.0
# 1970      536545     21134  Không biết         1  12/1/2010 14:32        0.0
# 1971      536546     22145  Không biết         1  12/1/2010 14:33        0.0
# 1972      536547     37509  Không biết         1  12/1/2010 14:33        0.0
# 1987      536549    85226A  Không biết         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581  Không biết        -2  12/7/2011 18:26        0.0
# 535326    581203     23406  Không biết        15  12/7/2011 18:31        0.0
# 535332    581209     21620  Không biết         6  12/7/2011 18:35        0.0
# 536981    581234     72817  Không biết        27  12/8/2011 10:33        0.0
# 538554    581408     85175  Không biết        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %%
sns.boxplot(data=df[['Quantity', 'UnitPrice']])
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(data=df[['Quantity', 'UnitPrice']])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### Lọc dữ liệu quantity >0 và UnitPrice>0

# %%
data = df[df['Quantity']>0].copy()
data = data[data['UnitPrice']>0]
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
sns.kdeplot(data=data[['Quantity', 'UnitPrice']])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Từ hình trên ta có thể thấy vẫn có giá trị ảnh hưởng đến các kết luận, biểu đồ boxplot cho thấy outliner đến từ Quantity và cần check lại quantity có bất thường hay không, nếu có bất thường tiến hành loại outlier \

# %% [markdown]
# #### 2. Xây dựng bảng Pivot table, với mỗi Số hóa đơn tính trung bình cộng số lượng các mặt hàng theo từng Quốc gia.

# %%
data.pivot_table(values='Quantity', index='Country', aggfunc='mean')
# Out:
#                        Quantity
# Country
# Australia             70.982234
# Austria               12.263819
# Bahrain               17.444444
# Belgium               11.441162
# Brazil                11.125000
# Canada                18.298013
# Channel Islands       12.688503
# Cyprus                10.359935
# Czech Republic        26.840000
# Denmark               21.671053
# EIRE                  18.653105
# European Community     8.316667
# Finland               15.626277
# France                13.334483
# Germany               13.192588
# Greece                10.737931
# Hong Kong             16.806338
# Iceland               13.505495
# Israel                14.945763
# Italy                 10.701847
# Japan                 81.046729
# Lebanon                8.577778
# Lithuania             18.628571
# Malta                  8.660714
# Netherlands           84.934718
# Norway                18.054155
# Poland                11.163636
# Portugal              10.831446
# ...

# %% [markdown]
# #### 3.Xây dựng bảng Pivot table, với mỗi Khách hàng cho biết số lượng mua hàng lớn nhất và nhỏ nhất theo Kho.

# %%
data.pivot_table(values='Quantity',columns ='StockCode',index='CustomerID',  aggfunc={min, max})
# Out:
#              max                                                           \
# StockCode  10002 10080 10120 10123C 10124A 10124G 10125 10133 10135 11001
# CustomerID
# 12346.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 12347.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 12348.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 12349.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 12350.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...    ...    ...    ...   ...   ...   ...   ...
# 18280.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 18281.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 18282.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 18283.0      NaN   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# #### 4.Xây dựng bảng Pivot table, với mỗi Mã kho tính tổng số lượng các mặt hàng và trung bình cộng giá.

# %%
import numpy as np
data.pivot_table(values=['Quantity','UnitPrice'], index='StockCode', aggfunc ={'Quantity':np.sum,'UnitPrice':np.mean})
# Out:
#               Quantity  UnitPrice
# StockCode
# 10002              860   1.086620
# 10080              303   0.410909
# 10120              193   0.210000
# 10123C               5   0.650000
# 10124A              16   0.420000
# ...                ...        ...
# gift_0001_20        10  16.708889
# gift_0001_30         7  25.075714
# gift_0001_40         3  33.566667
# gift_0001_50         4  41.890000
# m                    1   2.550000
#
# [3922 rows x 2 columns]

# %% [markdown]
# #### 5.Xây dựng bảng Pivot table cho biết tổng số lượng hàng bán được của mỗi ngày.

# %%
data['Date'] = data.loc[:,'InvoiceDate'].str.split(' ').str[0]
data.pivot_table(values='Quantity', index='Date', aggfunc='sum')
# Out:
#            Quantity
# Date
# 1/10/2011     12868
# 1/11/2011     28448
# 1/12/2011     10622
# 1/13/2011     10174
# 1/14/2011     23149
# ...             ...
# 9/5/2011      22893
# 9/6/2011      15090
# 9/7/2011      16390
# 9/8/2011      17466
# 9/9/2011      17405
#
# [305 rows x 1 columns]

# %% [markdown]
# #### 1.Công ty bán hàng do bao nhiêu nước sản xuất<br> 2.Tổng số lượng đơn hàng bán ra, tổng doanh thu<br> 3.Top 10 mặt hàng có số lượng bán ra lớn nhất<br> 4.Top 10 mặt hàng có doanh thu lớn nhất

# %%
print('The number of coutries are: ',data['Country'].nunique())
# Out:
# The number of coutries are:  38

# %%
data['Revenues'] = data['Quantity']*data['UnitPrice']
revenue_number = data['Revenues'].sum()
order_number=data['Quantity'].sum()
print('Total number of orders: ', order_number)
print('Total revenues: ', round(revenue_number,0))
# Out:
# Total number of orders:  5588376
# Total revenues:  10666685.0

# %%
data_pivot1 = data.pivot_table(values='Quantity', index=['Description'],aggfunc='sum')
data_pivot1 = data_pivot1.sort_values(by ='Quantity', ascending=False)
data_pivot1.iloc[:10]
# Out:
#                                     Quantity
# Description
# PAPER CRAFT , LITTLE BIRDIE            80995
# MEDIUM CERAMIC TOP STORAGE JAR         78033
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      55047
# JUMBO BAG RED RETROSPOT                48474
# WHITE HANGING HEART T-LIGHT HOLDER     37891
# POPCORN HOLDER                         36761
# ASSORTED COLOUR BIRD ORNAMENT          36461
# PACK OF 72 RETROSPOT CAKE CASES        36419
# RABBIT NIGHT LIGHT                     30788
# MINI PAINT SET VINTAGE                 26633

# %%
data_pivot1 = data.pivot_table(values='Revenues', index=['Description'],aggfunc='sum')
data_pivot1 = data_pivot1.sort_values(by ='Revenues', ascending=False)
data_pivot1.iloc[:10]
# Out:
#                                      Revenues
# Description
# DOTCOM POSTAGE                      206248.77
# REGENCY CAKESTAND 3 TIER            174484.74
# PAPER CRAFT , LITTLE BIRDIE         168469.60
# WHITE HANGING HEART T-LIGHT HOLDER  106292.77
# PARTY BUNTING                        99504.33
# JUMBO BAG RED RETROSPOT              94340.05
# MEDIUM CERAMIC TOP STORAGE JAR       81700.92
# Manual                               78112.82
# POSTAGE                              78101.88
# RABBIT NIGHT LIGHT                   66964.99

# %% [markdown]
# 1. Tạo cột mới có tên quý –  ‘Previous’ nhận giá trị 1 nếu ngày lập hóa đơn nằm trong các tháng 1,2,3; nhận giá trị 2 nếu ngày lập hóa đơn nằm trong các tháng 4,5,6; nhận giá trị 3 nếu ngày lập hóa đơn nằm trong các tháng 7,8,9;  nhận giá trị 4 nếu ngày lập hóa đơn nằm trong các tháng 10,11,12;<br>

# %%
data['Month'] = pd.to_datetime(data['Date']).dt.month
data['Month'].info()
condition = [(data['Month'] ==1) | (data['Month'] ==2) | (data['Month'] ==3), 
             (data['Month'] ==4) | (data['Month'] ==5) | (data['Month'] ==6),
             (data['Month'] ==7) | (data['Month'] ==8) | (data['Month'] ==9),
             (data['Month'] ==10) | (data['Month'] ==11) | (data['Month'] ==12)]
choices =[1,2,3,4]
data['Previous'] = np.select(condition, choices)
data.head(5)
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 530104 entries, 0 to 541908
# Series name: Month
# Non-Null Count   Dtype
# --------------   -----
# 530104 non-null  int64
# dtypes: int64(1)
# memory usage: 8.1 MB
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country       Date  Revenues  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  12/1/2010     15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  12/1/2010     20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  12/1/2010     22.00
# ...

# %% [markdown]
# 3. Tạo cột mới ‘Discount’ nhận giá trị 10% nếu Country là ‘United Kingdom’ và thuộc quý 4, 5% nếu là ‘France’ ngược lại là 0%.<br>

# %%
condition_discount = [(data['Country']=='United Kingdom') & (data['Previous']==4), (data['Country']=='France')]
choice_discount =[0.1, 0.05]
data['Discount'] = np.select(condition_discount, choice_discount, 0)
data.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country       Date  Revenues  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  12/1/2010     15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  12/1/2010     20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  12/1/2010     22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  12/1/2010     20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  12/1/2010     20.34
#
#    Month  Previous  Discount
# 0     12         4       0.1
# ...

# %% [markdown]
# 4. Tạo cột mới ‘Total’ nhận giá trị bằng: Amount – Discount

# %%
data['Total Revenues after Discount'] = data['Revenues'] - data['Revenues']*data['Discount']
data['Total Revenues after Discount']
# Out:
# 0         13.7700
# 1         18.3060
# 2         19.8000
# 3         18.3060
# 4         18.3060
#            ...
# 541904     9.6900
# 541905    11.9700
# 541906    15.7700
# 541907    15.7700
# 541908    14.1075
# Name: Total Revenues after Discount, Length: 530104, dtype: float64
